# %% [markdown]
# # Linear Regression
#
# In this project, I build a linear regression model from scratch without using pre-built training functions.
# I generate synthetic data with two features and predict a target variable using simple linear regression concepts.
#
# ## What is Linear Regression?
#
# Linear regression is one of the most basic and powerful tools in machine learning.
# It tries to find the best straight line (or hyperplane) that explains the relationship between input features (`X`) and the output (`y`).
# The goal is to minimize the difference between the predicted values and the true values.
#
# ## Learning Process
#
# The model learns by finding the best-fitting coefficients (slopes) and an intercept (bias) that minimize the error.
# I use the **Ordinary Least Squares (OLS)** method to calculate the parameters.
# OLS works by minimizing the sum of squared differences between the actual and predicted values.
#
# ## Strengths
#
# - Easy to understand and interpret.
# - Fast to train, even on large datasets.
# - Works well when there is a clear linear relationship between inputs and outputs.
# - Provides insights into feature importance through coefficients.
#
# ## Limitations
#
# - Struggles when the true relationship is non-linear.
# - Sensitive to outliers, which can distort the results.
# - Assumes that errors are normally distributed and have constant variance (homoscedasticity).
# - Multicollinearity (high correlation between features) can affect the stability of coefficients.
#
# This project helps me better understand how a linear regression model actually works under the hood, beyond simply calling a library function.

# %% [markdown]
# # 📚 Step 1: Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold

# %% [markdown]
# # 🎯 Step 2: Load and Preprocess the Housing Dataset

# %%
df = pd.read_csv('housing.csv')

# Display info and preview
print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB
# None
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# ...

# %%
# Check missing values
print(df.isnull().sum())

# Fill missing values in 'total_bedrooms' with median
df['total_bedrooms'] = df['total_bedrooms'].fillna(df['total_bedrooms'].median())

# Select Features and Target
features = ['median_income', 'housing_median_age', 'total_rooms']
X = df[features].values
y = df['median_house_value'].values.reshape(-1, 1)
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %% [markdown]
# # Project Analysis and Reflections
# In this project, I built a custom Linear Regression model to predict median house values using the California Housing dataset.
#
# I selected median_income, housing_median_age, and total_rooms as my features.
# Before modeling, I explored the data through various plots to better understand the relationships.

# %% [markdown]
# # 🎨 Step 3: Plot features vs target

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

for idx, feature in enumerate(features):
    axes[idx].scatter(X[:, idx], y, alpha=0.5)
    axes[idx].set_title(f"{feature} vs median_house_value")
    axes[idx].set_xlabel(feature)
    axes[idx].set_ylabel('median_house_value')

plt.tight_layout()
plt.show()

# %% [markdown]
# #  Feature-Target Relationships
# Median Income vs Median House Value:
# I observed a clear positive relationship. As the median income increases, the median house value also tends to increase.
# However, at very high income levels, the data points start to cluster around the top housing values, possibly due to a price ceiling effect.
#
# Housing Median Age vs Median House Value:
# This relationship was much weaker. The house value does not change strongly with the age of the house.
# The points are spread out, suggesting housing age is not a strong predictor by itself.
#
# Total Rooms vs Median House Value:
# There is a slight upward trend, but a lot of noise. Houses with more rooms can have higher values, but many exceptions exist.
# The spread of points is very wide, meaning room count alone does not reliably explain house price.

# %% [markdown]
# # 📈 Scatter + Trendline

# %%
import seaborn as sns

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

for idx, feature in enumerate(features):
    sns.regplot(x=df[feature], y=df['median_house_value'], ax=axes[idx], scatter_kws={'alpha':0.5})
    axes[idx].set_xlabel(feature)
    axes[idx].set_ylabel('Median House Value')
    axes[idx].set_title(f'{feature} vs Median House Value')
    axes[idx].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 🚀 Step 4: Define Advanced Linear Regression Class

# %%
class AdvancedLinearRegression:
    def __init__(self):
        self.coef_ = None
        self.intercept_ = None
        self.residuals_ = None
    
    def fit(self, X, y):
        X_b = np.c_[np.ones((X.shape[0], 1)), X]
        try:
            theta = np.linalg.inv(X_b.T @ X_b) @ X_b.T @ y
            self.intercept_ = theta[0]
            self.coef_ = theta[1:]
            self.residuals_ = y - self.predict(X)
        except np.linalg.LinAlgError:
            raise ValueError("Matrix is singular. Check for multicollinearity.")
    
    def predict(self, X):
        return self.intercept_ + X @ self.coef_
    
    def r_squared(self, y_true, y_pred):
        ss_res = np.sum((y_true - y_pred) ** 2)
        ss_tot = np.sum((y_true - np.mean(y_true)) ** 2)
        return 1 - (ss_res / ss_tot)
    
    def summary(self, X, y):
        y_pred = self.predict(X)
        X_b = np.c_[np.ones((X.shape[0], 1)), X]
        n, p = X_b.shape
        mse = np.sum(self.residuals_ ** 2) / (n - p)
        cov_matrix = mse * np.linalg.inv(X_b.T @ X_b)
        se_coef = np.sqrt(np.diag(cov_matrix))
        
        t_stats = (np.concatenate([self.intercept_, self.coef_.flatten()]) / se_coef)
        p_values = 2 * (1 - stats.t.cdf(np.abs(t_stats), df=n-p))
        
        print(f"Intercept: {self.intercept_[0]:.4f} (SE: {se_coef[0]:.4f}, t: {t_stats[0]:.4f}, p: {p_values[0]:.4f})")
        for i in range(len(self.coef_)):
            print(f"{features[i]} coef: {self.coef_[i][0]:.4f} (SE: {se_coef[i+1]:.4f}, t: {t_stats[i+1]:.4f}, p: {p_values[i+1]:.4f})")
        print(f"R²: {self.r_squared(y, y_pred):.4f}")

# %% [markdown]
# # 🛠️ Step 5: Train the Custom Linear Regression Model

# %%
model = AdvancedLinearRegression()
model.fit(X, y)
model.summary(X, y)
# Out:
# Intercept: -24329.8794 (SE: 2160.3261, t: -11.2621, p: 0.0000)
# median_income coef: 42467.0389 (SE: 301.2300, t: 140.9788, p: 0.0000)
# housing_median_age coef: 1974.9806 (SE: 47.7989, t: 41.3186, p: 0.0000)
# total_rooms coef: 3.8878 (SE: 0.2793, t: 13.9188, p: 0.0000)
# R²: 0.5137

# %% [markdown]
# # Step 6: Compare with Scikit-learn LinearRegression

# %%
sklearn_model = LinearRegression().fit(X, y)
print("\n--- Comparison with Scikit-learn ---")
print("Intercept:", sklearn_model.intercept_[0])
print("Coefficients:", sklearn_model.coef_[0])
print("R²:", sklearn_model.score(X, y))
# Out:
# --- Comparison with Scikit-learn ---
# Intercept: -24329.879420558456
# Coefficients: [4.24670389e+04 1.97498062e+03 3.88780381e+00]
# R²: 0.5136851787430972

# %% [markdown]
# # Step 7: Feature Scaling

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

model_scaled = AdvancedLinearRegression()
model_scaled.fit(X_scaled, y)
print("\n--- After Feature Scaling ---")
model_scaled.summary(X_scaled, y)
# Out:
# --- After Feature Scaling ---
# Intercept: 206855.8169 (SE: 560.1764, t: 369.2691, p: 0.0000)
# median_income coef: 80677.8483 (SE: 572.2695, t: 140.9788, p: 0.0000)
# housing_median_age coef: 24855.6302 (SE: 601.5608, t: 41.3186, p: 0.0000)
# total_rooms coef: 8481.4866 (SE: 609.3539, t: 13.9188, p: 0.0000)
# R²: 0.5137

# %% [markdown]
# # Step 8: Cross-Validation (5-Fold)

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=42)
r2_scores = []

for train_idx, test_idx in kf.split(X_scaled):
    X_train, X_test = X_scaled[train_idx], X_scaled[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]
    
    model_cv = AdvancedLinearRegression()
    model_cv.fit(X_train, y_train)
    y_pred = model_cv.predict(X_test)
    
    r2_scores.append(model_cv.r_squared(y_test, y_pred))

print(f"\nMean R² across 5 folds: {np.mean(r2_scores):.4f}")
# Out:
# Mean R² across 5 folds: 0.5134

# %% [markdown]
# #  Model Summary and Results
# After fitting my custom Linear Regression model, the R² score was around 0.51.
#
# This means my model explains about 51% of the variance in the median house values, which is reasonable but leaves room for improvement.
#
# After standardizing features using StandardScaler, the model performance stayed almost the same.
# This shows that although standardization helps with numerical stability, it didn’t drastically improve the predictive power in this case.
#
# The cross-validation (5-fold) confirmed this performance, with an average R² score around 0.5134.

# %% [markdown]
# # Step 9: Residual Analysis

# %%
plt.figure(figsize=(10, 5))
plt.scatter(model.predict(X), model.residuals_, alpha=0.5)
plt.axhline(y=0, color='red', linestyle='--')
plt.xlabel("Predicted Median House Value")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.grid(True)
plt.show()

# %% [markdown]
# # Residual Analysis
# Residual Plot:
# The residuals (errors) are not randomly scattered around zero.
# There is a clear funnel shape, meaning heteroscedasticity exists.
# The model's errors get bigger as the predicted house value increases.
# This suggests the linear model might not fully capture the variability in expensive houses.
#
# Residual Distribution:
# The residuals are roughly centered around zero and show a somewhat normal distribution, but they are not perfectly symmetric.
# There are a few extreme values (outliers) which may be influencing the model's performance.

# %% [markdown]
# # Additional: Residual Distribution

# %%
sns.histplot(model.residuals_.flatten(), kde=True, bins=30)
plt.title("Residuals Distribution")
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %% [markdown]
# # Conclusions
# Median income is clearly the most important feature out of the three I selected.
#
# Housing age and total rooms have weaker predictive power.
#
# Linear Regression captures the general trend but struggles with extreme values and variance in expensive properties.
#
# I learned that real-world housing data can have noise, outliers, and non-linear relationships that make simple models less effective.
#
# In future work, I could try more advanced models like polynomial regression, decision trees, or random forests to better capture complex patterns.
